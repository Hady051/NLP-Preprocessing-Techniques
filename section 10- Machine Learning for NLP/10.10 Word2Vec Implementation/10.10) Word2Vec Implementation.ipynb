# %% [markdown]
# ## <span style="color:orange">Word2Vec used model</span>

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
## References: https://stackoverflow.com/questions/46433778/import-googlenews-vectors-negative300-bin

# %%
from gensim import downloader as api

word_2_vec = api.load('word2vec-google-news-300')   # // took 15m, 23sec
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
vector_king = word_2_vec['king']

# %%
vector_king

# // as was discussed before this vector (and every vector) contains 300 dimensions
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
vector_king.shape
# Out:
# (300,)

# %%
word_2_vec['lion']
# Out:
# array([ 2.12890625e-01, -4.57763672e-03, -2.36328125e-01,  4.56542969e-02,
#         1.34765625e-01, -1.36718750e-01, -1.40991211e-02, -1.22558594e-01,
#         3.80859375e-02, -2.12097168e-03, -1.57226562e-01,  5.92041016e-03,
#        -1.87500000e-01, -9.86328125e-02, -4.64843750e-01, -3.27148438e-02,
#        -2.51953125e-01,  1.50146484e-02, -2.37304688e-01, -1.05468750e-01,
#        -6.44531250e-02, -2.19726562e-01,  3.80859375e-01, -6.78710938e-02,
#         1.67968750e-01,  1.31835938e-01, -3.65234375e-01,  9.08203125e-02,
#         1.94335938e-01,  2.12097168e-03, -1.25000000e-01, -1.01074219e-01,
#        -2.05078125e-02,  1.79687500e-01, -6.29882812e-02, -1.00097656e-01,
#        -3.82812500e-01,  2.73437500e-01,  1.89453125e-01,  2.61718750e-01,
#         2.14843750e-01, -2.03125000e-01,  1.56250000e-01,  2.15820312e-01,
#         1.06933594e-01, -3.12500000e-02,  2.41210938e-01, -1.20239258e-02,
# ...

# %%
word_2_vec['money']
# Out:
# array([ 1.58203125e-01,  5.12695312e-02,  6.64062500e-02,  2.10937500e-01,
#         3.51562500e-02, -4.66918945e-03, -4.45556641e-03, -8.20312500e-02,
#         1.88476562e-01, -1.51367188e-01,  1.58203125e-01,  1.60156250e-01,
#        -1.26953125e-01,  1.97265625e-01, -2.61718750e-01,  1.68945312e-01,
#        -6.64062500e-02,  1.76757812e-01, -3.54003906e-02,  1.87500000e-01,
#         8.44726562e-02,  1.63085938e-01,  1.93359375e-01,  1.30859375e-01,
#         6.59179688e-02,  9.52148438e-02, -9.96093750e-02,  1.15234375e-01,
#        -1.28906250e-01, -1.22558594e-01, -1.14257812e-01,  2.17285156e-02,
#         9.91210938e-02, -7.22656250e-02,  9.57031250e-02, -1.38671875e-01,
#         1.52343750e-01, -7.81250000e-03, -5.78613281e-02,  5.24902344e-02,
#         1.82617188e-01,  7.66601562e-02,  2.59765625e-01, -3.00781250e-01,
#        -3.08593750e-01, -1.68945312e-01, -1.29882812e-01,  2.61718750e-01,
# ...

# %%
## To show the most similar words

word_2_vec.most_similar('happy')
# Out:
# [('glad', 0.7408890724182129),
#  ('pleased', 0.6632170677185059),
#  ('ecstatic', 0.6626912355422974),
#  ('overjoyed', 0.6599286794662476),
#  ('thrilled', 0.6514049172401428),
#  ('satisfied', 0.6437949538230896),
#  ('proud', 0.636042058467865),
#  ('delighted', 0.627237856388092),
#  ('disappointed', 0.6269949674606323),
#  ('excited', 0.6247665286064148)]

# %%
## To give two words and compute how much similar they are

word_2_vec.similarity("hockey", "sports")
# Out:
# 0.53541523

# %%
word_2_vec.similarity("football", "basketball")
# Out:
# 0.66824675

# %%
vector = word_2_vec['king'] - word_2_vec['man'] + word_2_vec['woman']

# %%
vector
# Out:
# array([ 4.29687500e-02, -1.78222656e-01, -1.29089355e-01,  1.15234375e-01,
#         2.68554688e-03, -1.02294922e-01,  1.95800781e-01, -1.79504395e-01,
#         1.95312500e-02,  4.09919739e-01, -3.68164062e-01, -3.96484375e-01,
#        -1.56738281e-01,  1.46484375e-03, -9.30175781e-02, -1.16455078e-01,
#        -5.51757812e-02, -1.07574463e-01,  7.91015625e-02,  1.98974609e-01,
#         2.38525391e-01,  6.34002686e-02, -2.17285156e-02,  0.00000000e+00,
#         4.72412109e-02, -2.17773438e-01, -3.44726562e-01,  6.37207031e-02,
#         3.16406250e-01, -1.97631836e-01,  8.59375000e-02, -8.11767578e-02,
#        -3.71093750e-02,  3.15551758e-01, -3.41796875e-01, -4.68750000e-02,
#         9.76562500e-02,  8.39843750e-02, -9.71679688e-02,  5.17578125e-02,
#        -5.00488281e-02, -2.20947266e-01,  2.29492188e-01,  1.26403809e-01,
#         2.49023438e-01,  2.09960938e-02, -1.09863281e-01,  5.81054688e-02,
# ...

# %%
word_2_vec.most_similar([vector] )
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300517559051514),
#  ('monarch', 0.645466148853302),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676352500916),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613663792610168),
#  ('sultan', 0.5376775860786438),
#  ('Queen_Consort', 0.5344247817993164),
#  ('queens', 0.5289887189865112)]
